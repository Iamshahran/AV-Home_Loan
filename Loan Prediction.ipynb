# %% [markdown]
# # Mohammad Shehran Siddiqui
# ### +91-7237957875

# %% [markdown]
# ### Analytic Vidhya - Loan Pridiction Classifier

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("train_ctrUa4K.csv",index_col = 'Loan_ID')
data.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
# LP002990  Female      No          0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# ...

# %%
data.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(data = data, x = 'Gender')

# %%
data['Gender'].fillna('Male',inplace = True)

# %%
data['Gender'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data = data, x = 'Dependents')

# %%
data['Dependents'].fillna('0',inplace = True)

# %%
sns.countplot(data = data, x = 'Dependents')

# %%
sns.countplot(data = data, x = 'Self_Employed')

# %%
data['Self_Employed'].fillna('No',inplace = True)

# %%
data.isnull().sum()
# Out:
# Gender                0
# Married               3
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
plt.figure(figsize = (8,5))
#sns.boxplot(data =data,x='LoanAmount')
sns.boxplot(data =data,x='Loan_Amount_Term')

# %%
data['LoanAmount'].fillna('128',inplace = True)

# %%
data['Loan_Amount_Term'].fillna('360',inplace = True)

# %%
data['Credit_History'].fillna('1.0',inplace = True)

# %%
data.dropna(axis = 0, how ='any',inplace = True)

# %%
data.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
# LP002990  Female      No          0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0        128              360
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
new_df = data

# %%
gender_data = pd.get_dummies(new_df['Gender'])

# %%
new_df['Male'] = gender_data['Male'].to_list()
new_df['Female'] = gender_data['Female'].to_list()

# %%
new_df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0        128              360
# LP001003             4583             1508.0        128              360
# LP001005             3000                0.0         66              360
# LP001006             2583             2358.0        120              360
# LP001008             6000                0.0        141              360
#
#          Credit_History Property_Area Loan_Status  Male  Female
# Loan_ID
# ...

# %%
married_data = pd.get_dummies(new_df['Married'])
married_data.head(2)
# Out:
#           No  Yes
# Loan_ID
# LP001002   1    0
# LP001003   0    1

# %%
new_df['Married_No'] = married_data['No'].to_list()
new_df['Married_Yes'] = married_data['Yes'].to_list()

# %%
education_data = pd.get_dummies(data['Education'])

# %%
new_df['Education_Graduate'] = education_data['Graduate'].to_list()
new_df['Education_NotGraduate'] = education_data['Not Graduate'].to_list()

# %%
new_df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0        128              360
# LP001003             4583             1508.0        128              360
# LP001005             3000                0.0         66              360
# LP001006             2583             2358.0        120              360
# LP001008             6000                0.0        141              360
#
#          Credit_History Property_Area Loan_Status  Male  Female  Married_No  \
# Loan_ID
# ...

# %%
self_employed_data = pd.get_dummies(new_df['Self_Employed'])

# %%
new_df['Self_Employed_No'] = self_employed_data['No'].to_list()
new_df['Self_Employed_Yes'] = self_employed_data['Yes'].to_list()

# %%
new_df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0        128              360
# LP001003             4583             1508.0        128              360
# LP001005             3000                0.0         66              360
# LP001006             2583             2358.0        120              360
# LP001008             6000                0.0        141              360
#
#          Credit_History Property_Area Loan_Status  Male  Female  Married_No  \
# Loan_ID
# ...

# %%
property_data = pd.get_dummies(new_df['Property_Area'])

# %%
new_df['Rural'] = property_data['Rural'].to_list()
new_df['Sumiurban'] = property_data['Semiurban'].to_list()
new_df['Urban'] = property_data['Urban'].to_list()

# %%
new_df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0        128              360
# LP001003             4583             1508.0        128              360
# LP001005             3000                0.0         66              360
# LP001006             2583             2358.0        120              360
# LP001008             6000                0.0        141              360
#
#          Credit_History  ... Female Married_No  Married_Yes  \
# Loan_ID                  ...
# ...

# %%
final_df = new_df.drop(['Gender','Married','Education','Self_Employed','Property_Area'],axis = 'columns')

# %%
final_df.head()
# Out:
#          Dependents  ApplicantIncome  CoapplicantIncome LoanAmount  \
# Loan_ID
# LP001002          0             5849                0.0        128
# LP001003          1             4583             1508.0        128
# LP001005          0             3000                0.0         66
# LP001006          0             2583             2358.0        120
# LP001008          0             6000                0.0        141
#
#          Loan_Amount_Term Credit_History Loan_Status  Male  Female  \
# Loan_ID
# LP001002              360              1           Y     1       0
# LP001003              360              1           N     1       0
# LP001005              360              1           Y     1       0
# LP001006              360              1           Y     1       0
# LP001008              360              1           Y     1       0
#
#           Married_No  Married_Yes  Education_Graduate  Education_NotGraduate  \
# Loan_ID
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 611 entries, LP001002 to LP002990
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Dependents             611 non-null    object
#  1   ApplicantIncome        611 non-null    int64
#  2   CoapplicantIncome      611 non-null    float64
#  3   LoanAmount             611 non-null    object
#  4   Loan_Amount_Term       611 non-null    object
#  5   Credit_History         611 non-null    object
#  6   Loan_Status            611 non-null    object
#  7   Male                   611 non-null    int64
#  8   Female                 611 non-null    int64
#  9   Married_No             611 non-null    int64
#  10  Married_Yes            611 non-null    int64
#  11  Education_Graduate     611 non-null    int64
#  12  Education_NotGraduate  611 non-null    int64
#  13  Self_Employed_No       611 non-null    int64
# ...

# %%
final_df['LoanAmount'] = final_df['LoanAmount'].astype(str).astype(float)

# %%
final_df['Loan_Amount_Term'] = final_df['Loan_Amount_Term'].astype(str).astype(float)

# %%
final_df['Credit_History'] = final_df['Credit_History'].astype(str).astype(float)

# %%
final_df = final_df.replace('3+','3')
#x['Dependents'].unique()

# %%
final_df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3'], dtype=object)

# %%
final_df.head(10)
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0          0             5849                0.0        128              360
# 1          1             4583             1508.0        128              360
# 2          0             3000                0.0         66              360
# 3          0             2583             2358.0        120              360
# 4          0             6000                0.0        141              360
# 5          2             5417             4196.0        267              360
# 6          0             2333             1516.0         95              360
# 7          3             3036             2504.0        158              360
# 8          2             4006             1526.0        168              360
# 9          1            12841            10968.0        349              360
#
#   Credit_History Loan_Status  Male  Female  Married_No  Married_Yes  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Dependents             611 non-null    object
#  1   ApplicantIncome        611 non-null    int64
#  2   CoapplicantIncome      611 non-null    float64
#  3   LoanAmount             611 non-null    object
#  4   Loan_Amount_Term       611 non-null    object
#  5   Credit_History         611 non-null    object
#  6   Loan_Status            611 non-null    object
#  7   Male                   611 non-null    int64
#  8   Female                 611 non-null    int64
#  9   Married_No             611 non-null    int64
#  10  Married_Yes            611 non-null    int64
#  11  Education_Graduate     611 non-null    int64
#  12  Education_NotGraduate  611 non-null    int64
#  13  Self_Employed_No       611 non-null    int64
# ...

# %%
#pip install xgboost

# %%
final_df['Dependents'] = final_df['Dependents'].replace('3+','3')

# %%
final_df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3'], dtype=object)

# %%
final_df.replace('3+','3')
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0       128.0
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610          3             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History Loan_Status  Male  Female  Married_No  \
# 0               360.0             1.0           Y     1       0           1
# ...

# %%
final_df['Dependents'] = final_df['Dependents'].astype(str).astype(float)

# %%
final_df.replace('3+','3')
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0       128.0
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610          3             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History Loan_Status  Male  Female  Married_No  \
# 0               360.0             1.0           Y     1       0           1
# ...

# %% [markdown]
# ## Read test file

# %%
df2 = pd.read_csv('test_lAUu6dG.csv',index_col = 'Loan_ID')
df2.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001015   Male     Yes          0      Graduate            No
# LP001022   Male     Yes          1      Graduate            No
# LP001031   Male     Yes          2      Graduate            No
# LP001035   Male     Yes          2      Graduate            No
# LP001051   Male      No          0  Not Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001015             5720                  0       110.0             360.0
# LP001022             3076               1500       126.0             360.0
# LP001031             5000               1800       208.0             360.0
# LP001035             2340               2546       100.0             360.0
# LP001051             3276                  0        78.0             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001015             1.0         Urban
# ...

# %%
df2.isnull().sum()
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
sns.countplot(data = df2,x = 'Gender')

# %%
df2['Gender'].fillna('Male',inplace = True)

# %%
sns.countplot(data = df2,x='Dependents')

# %%
df2['Dependents'].fillna(0,inplace = True)

# %%
sns.countplot(data = df2,x = 'Self_Employed')

# %%
df2['Self_Employed'].fillna('No',inplace = True)

# %%
sns.boxplot(data = df2,x = 'LoanAmount')

# %%
sns.boxplot(data = df2,x = 'Loan_Amount_Term')

# %%
sns.boxplot(data = df2,x = 'Credit_History')

# %%
df2.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df2['LoanAmount'].fillna(125,inplace = True)

# %%
df2['Loan_Amount_Term'].fillna(360,inplace = True)

# %%
df2['Credit_History'].fillna(1,inplace = True)

# %%
df2.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
final_test = df2

# %%
#test data dummies
gender_data2 = pd.get_dummies(df2['Gender'])
final_test['Male'] = gender_data2['Male'].to_list()
final_test['Female'] = gender_data2['Female'].to_list()
married_data2 = pd.get_dummies(df2['Married'])
final_test['Married_No'] = married_data2['No'].to_list()
final_test['Married_Yes'] = married_data2['Yes'].to_list()
education_data2 = pd.get_dummies(df2['Education'])
final_test['Education_Graduate'] = education_data2['Graduate'].to_list()
final_test['Education_NotGraduate'] = education_data2['Not Graduate'].to_list()
self_employed_data2 = pd.get_dummies(df2['Self_Employed'])
final_test['Self_Employed_No'] = self_employed_data2['No'].to_list()
final_test['Self_Employed_Yes'] = self_employed_data2['Yes'].to_list()
property_data2 = pd.get_dummies(df2['Property_Area'])
final_test['Rural'] = property_data2['Rural'].to_list()
final_test['Sumiurban'] = property_data2['Semiurban'].to_list()
final_test['Urban'] = property_data2['Urban'].to_list()

# %%
final_test.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001015   Male     Yes          0      Graduate            No
# LP001022   Male     Yes          1      Graduate            No
# LP001031   Male     Yes          2      Graduate            No
# LP001035   Male     Yes          2      Graduate            No
# LP001051   Male      No          0  Not Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001015             5720                  0       110.0             360.0
# LP001022             3076               1500       126.0             360.0
# LP001031             5000               1800       208.0             360.0
# LP001035             2340               2546       100.0             360.0
# LP001051             3276                  0        78.0             360.0
#
#           Credit_History  ... Female  Married_No  Married_Yes  \
# Loan_ID                   ...
# ...

# %%
final_test = final_test.drop(['Gender','Married','Education','Self_Employed','Property_Area'],axis = 'columns')

# %%
final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 367 entries, LP001015 to LP002989
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Dependents             367 non-null    object
#  1   ApplicantIncome        367 non-null    int64
#  2   CoapplicantIncome      367 non-null    int64
#  3   LoanAmount             367 non-null    float64
#  4   Loan_Amount_Term       367 non-null    float64
#  5   Credit_History         367 non-null    float64
#  6   Male                   367 non-null    int64
#  7   Female                 367 non-null    int64
#  8   Married_No             367 non-null    int64
#  9   Married_Yes            367 non-null    int64
#  10  Education_Graduate     367 non-null    int64
#  11  Education_NotGraduate  367 non-null    int64
#  12  Self_Employed_No       367 non-null    int64
#  13  Self_Employed_Yes      367 non-null    int64
# ...

# %%
final_test['Dependents'] = final_test['Dependents'].replace('3+','3')

# %%
final_test['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3', 0], dtype=object)

# %%
final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 367 entries, LP001015 to LP002989
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Dependents             367 non-null    object
#  1   ApplicantIncome        367 non-null    int64
#  2   CoapplicantIncome      367 non-null    int64
#  3   LoanAmount             367 non-null    float64
#  4   Loan_Amount_Term       367 non-null    float64
#  5   Credit_History         367 non-null    float64
#  6   Male                   367 non-null    int64
#  7   Female                 367 non-null    int64
#  8   Married_No             367 non-null    int64
#  9   Married_Yes            367 non-null    int64
#  10  Education_Graduate     367 non-null    int64
#  11  Education_NotGraduate  367 non-null    int64
#  12  Self_Employed_No       367 non-null    int64
#  13  Self_Employed_Yes      367 non-null    int64
# ...

# %%
final_test['Dependents'] = final_test['Dependents'].astype(str).astype(float)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
import xgboost
from sklearn.model_selection import train_test_split

# %%
y = final_df['Loan_Status']
X = final_df.drop(['Loan_Status'],axis = 1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,shuffle = True)

# %%
classifiers = []
model1 = xgboost.XGBClassifier()
classifiers.append(model1)
model2 = svm.SVC()
classifiers.append(model2)
model3 = tree.DecisionTreeClassifier()
classifiers.append(model3)
model4 = RandomForestClassifier()
classifiers.append(model4)

# %%
model4.fit(X_train,y_train)
y_prid = model4.predict(X_test)
print('Random Forest')
acc = accuracy_score(y_test,y_prid)
print(acc)
cm = confusion_matrix(y_test,y_prid)
print(cm)
# Out:
# Random Forest
# 0.7989130434782609
# [[ 30  26]
#  [ 11 117]]

# %%
#model.fit(features,target)
#y_prid = model.predict(X_test)
#acc = accuracy_score(y_test,y_prid)
#cm = confusion_matrix(y_test,y_prid)

model3.fit(X_train,y_train)
y_prid = model3.predict(X_test)
acc = accuracy_score(y_test,y_prid)
print(acc)
cm = confusion_matrix(y_test,y_prid)
print(cm)
# Out:
# 0.7228260869565217
# [[ 31  25]
#  [ 26 102]]

# %%
model2.fit(X_train,y_train)
y_prid = model2.predict(X_test)
print('SVC')
acc = accuracy_score(y_test,y_prid)
print(acc)
cm = confusion_matrix(y_test,y_prid)
print(cm)
# Out:
# SVC
# 0.6956521739130435
# [[  0  56]
#  [  0 128]]

# %%
model1.fit(X_train,y_train)
y_prid = model1.predict(X_test)
print('XGBoost')
acc = accuracy_score(y_test,y_prid)
print(acc)
cm = confusion_matrix(y_test,y_prid)
print(cm)
# Out:
# C:\Users\Shehran\anaconda3\lib\site-packages\xgboost\sklearn.py:892: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:07:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost
# 0.7391304347826086
# [[ 29  27]
#  [ 21 107]]

# %%
rf = RandomForestClassifier()
rf.fit(X,y)
prid_test = rf.predict(final_test)

# %%
output = pd.DataFrame({'Loan_ID': final_test.index,
                      'Loan_Status': prid_test})
output.to_csv('my_submisssion.csv',index = False)
